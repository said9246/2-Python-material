# %%
print("Hello, World!")
# Out:
# Hello, World!

# %% [markdown]
# String method

# %%
name="my name is said ahmed"
print(name)
# Out:
# my name is said ahmed

# %%
print(len(name))
# Out:
# 21

# %%
print(name.upper())
# Out:
# MY NAME IS SAID AHMED

# %%
print(name.lower())
# Out:
# my name is said ahmed

# %%
words=name.split()
print(words)
# Out:
# ['my', 'name', 'is', 'said', 'ahmed']

# %%
print('-'.join(words))
# Out:
# my-name-is-said-ahmed

# %%
print('finsd positon of text:', name.find("said"))
# Out:
# finsd positon of text: 11

# %%
print ('name replace:', name.replace("ahmed", "Khan"))
# Out:
# name replace: my name is said Khan

# %%
print('check string start with' , name.startswith("my"))
# Out:
# check string start with True

# %%
print('chcek string end with', name.endswith("ahmed"))
# Out:
# chcek string end with True

# %%
print('print string reverse:    ', name[::-1])
# Out:
# print string reverse:     demha dias si eman ym

# %%
print('convert string to list:', list(name))
# Out:
# convert string to list: ['m', 'y', ' ', 'n', 'a', 'm', 'e', ' ', 'i', 's', ' ', 's', 'a', 'i', 'd', ' ', 'a', 'h', 'm', 'e', 'd']

# %%
print("check sting is prensen in text or not:", "said" in name)
# Out:
# check sting is prensen in text or not: True

# %%
print("my name is %s and i am %d years old" % ("said", 20 )  )
# Out:
# my name is said and i am 20 years old
